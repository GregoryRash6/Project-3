# %%
# Import Dependencies
import pandas as pd

# %%
# Define File Path
complete = "ufc_complete.csv"

# Read CSV
data = pd.read_csv(complete)

data
# Out:
#       no_of_rounds  B_current_lose_streak  B_current_win_streak  \
# 0                2                    0.0                   3.0
# 1                2                    0.0                   0.0
# 2                2                    0.0                   1.0
# 3                5                    0.0                   1.0
# 4                3                    0.0                   1.0
# ...            ...                    ...                   ...
# 4270             3                    1.0                   0.0
# 4271             3                    2.0                   0.0
# 4272             3                    2.0                   0.0
# 4273             3                    1.0                   0.0
# 4274             5                    0.0                   1.0
#
#       R_current_lose_streak  R_current_win_streak  B_total_rounds_fought  \
# 0                       0.0                   2.0                    3.0
# ...
