# %%
# %matplotlib notebook

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define File Path
complete = "ufc_feature_selection.csv"

# Read CSV
data = pd.read_csv(complete)

data
# Out:
#               B_fighter         R_fighter        date  \
# 0         Vitor Belfort     Randy Couture  1997-10-17
# 1         Chuck Liddell       Jeremy Horn  1999-03-05
# 2       Wanderlei Silva     Vitor Belfort  1998-10-16
# 3     Ildemar Alcantara      Wagner Prado  2013-01-19
# 4         Lucas Martins     Edson Barboza  2013-01-19
# ...                 ...               ...         ...
# 4270         Matt Brown      Miguel Baeza  2020-05-16
# 4271        Marlon Vera       Song Yadong  2020-05-16
# 4272        Eryk Anders   Krzysztof Jotko  2020-05-16
# 4273      Edson Barboza           Dan Ige  2020-05-16
# 4274        Walt Harris  Alistair Overeem  2020-05-16
#
#                              location       weight_class  no_of_rounds  \
# 0     Bay St. Louis, Mississippi, USA        Heavyweight             2
# 1     Bay St. Louis, Mississippi, USA       Middleweight             2
# 2                   Sao Paulo, Brazil       Middleweight             2
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e1ab6c09fe68> in <module>
# ----> 1 pd.DataFrame([x for x in zip(reg.feature_importances_, data.columns)]).plot(kind='bar', y=0, x=1)
#
# NameError: name 'reg' is not defined
