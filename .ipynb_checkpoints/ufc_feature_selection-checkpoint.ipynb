# %%
# %matplotlib notebook

# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define File Path
complete = "ufc_feature_selection.csv"

# Read CSV
data = pd.read_csv(complete)

data
# Out:
#       R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_wins  B_avg_SIG_STR_pct  \
# 0                             0.0              1.0     2.0           0.650000
# 1                             0.0              0.0     0.0           0.460000
# 2                             0.0              2.0     3.0           0.640000
# 3                             1.0              0.0     2.0           0.500000
# 4                             1.0              2.0     5.0           0.716667
# ...                           ...              ...     ...                ...
# 3327                          0.0              0.0     2.0           0.540000
# 3328                          0.0              0.0     5.0           0.480000
# 3329                          0.0              0.0     9.0           0.450000
# 3330                          0.0              0.0     6.0           0.430000
# 3331                          0.0              0.0    32.0           0.390000
#
# ...

# %%
sorted(data.columns)
# Out:
# ['B_Height_cms',
#  'B_Reach_cms',
#  'B_Stance_Open Stance',
#  'B_Stance_Orthodox',
#  'B_Stance_Southpaw',
#  'B_Stance_Switch',
#  'B_Weight_lbs',
#  'B_age',
#  'B_avg_SIG_STR_landed',
#  'B_avg_SIG_STR_pct',
#  'B_avg_SUB_ATT',
#  'B_avg_TD_landed',
#  'B_avg_TD_pct',
#  'B_current_lose_streak',
#  'B_current_win_streak',
#  'B_draw',
#  'B_fighter',
#  'B_longest_win_streak',
#  'B_losses',
#  'B_total_rounds_fought',
#  'B_total_title_bouts',
#  'B_win_by_Decision_Majority',
#  'B_win_by_Decision_Split',
#  'B_win_by_Decision_Unanimous',
#  'B_win_by_KO/TKO',
#  'B_win_by_Submission',
#  'B_win_by_TKO_Doctor_Stoppage',
#  'B_wins',
#  'R_Height_cms',
#  'R_Reach_cms',
#  'R_Stance_Open Stance',
#  'R_Stance_Orthodox',
#  'R_Stance_Southpaw',
#  'R_Stance_Switch',
#  'R_Weight_lbs',
#  'R_age',
#  'R_avg_SIG_STR_landed',
#  'R_avg_SIG_STR_pct',
#  'R_avg_SUB_ATT',
#  'R_avg_TD_landed',
#  'R_avg_TD_pct',
#  'R_current_lose_streak',
#  'R_current_win_streak',
#  'R_draw',
# ...
